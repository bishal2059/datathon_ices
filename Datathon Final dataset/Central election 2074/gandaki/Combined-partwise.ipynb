# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pt
import math

# %%
dfk1 = pd.read_csv('kaski/clean1.csv')
dfk2 = pd.read_csv('kaski/clean2.csv')
dfk3 = pd.read_csv('kaski/clean3.csv')

dfs1 = pd.read_csv('syangja/clean1.csv')
dfs2 = pd.read_csv('syangja/clean2.csv')

dfl1 = pd.read_csv('lamjung/clean1.csv')

dfb1=pd.read_csv('baglung/clean1.csv')
dfb2 =pd.read_csv('baglung/clean2.csv')

# %%
dfa= {
    "1":dfk1.iloc[0],
    "2":dfk2.iloc[0],
    "3":dfk3.iloc[0],
   "4":dfs1.iloc[0],
    "5":dfs2.iloc[0],
    "7":dfb1.iloc[0],
}

# %%
totala = pd.DataFrame(dfa)
# Out:
#                                                   1  \
# Unnamed: 0                                        0
# SerialNo                                       1311
# StateID                                         4.0
# CandidateName                         खगराज अधिकारी
# Gender                                        पुरुष
# Age                                              55
# PoliticalPartyName  नेपाल कम्युनिष्ट पार्टी (एमाले)
# DistrictName                                 कास्की
# CenterConstID                                   1.0
# TotalVotesReceived                            39242
# EStatus                                     Elected
# Rank                                              1
#
#                                                   2  \
# Unnamed: 0                                        0
# SerialNo                                     1322.0
# StateID                                           4
# CandidateName               रविन्द्र प्रसाद अधिकारी
# ...

# %%
dfk= {
    "1":dfk1.iloc[1],
    "2":dfk2.iloc[1],
    "3":dfk3.iloc[1],
   "4":dfs1.iloc[1],
    "5":dfs2.iloc[1],
    "6":dfl1.iloc[1],
    "7":dfb1.iloc[1],
    "8":dfb2.iloc[1]
}

# %%
totalk= pd.DataFrame(dfk)
# Out:
#                                    1                2                3  \
# Unnamed: 0                         1                1                1
# SerialNo                        1312           1323.0             1336
# StateID                          4.0                4                4
# CandidateName       यज्ञ बहादुर थापा   देव राज चालिसे   शुक्रराज शर्मा
# Gender                         पुरुष            पुरुष            पुरुष
# Age                               63               57             70.0
# PoliticalPartyName   नेपाली काँग्रेस  नेपाली काँग्रेस  नेपाली काँग्रेस
# DistrictName                  कास्की           कास्की           कास्की
# CenterConstID                    1.0                2              3.0
# TotalVotesReceived             25826          18661.0            24304
# EStatus                  Not Elected      Not Elected      Not Elected
# Rank                               2                2                2
#
# ...
