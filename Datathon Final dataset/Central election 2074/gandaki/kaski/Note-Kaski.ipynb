# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pt
import math

# %%
df1 = pd.read_csv('1.csv')
df2 = pd.read_csv('2.csv')
df3 = pd.read_csv('3.csv')

# %%
df1
# Out:
#     SerialNo  StateID          CandidateName Gender  Age  \
# 0       1311      4.0          खगराज अधिकारी  पुरुष   55
# 1       1312      4.0       यज्ञ बहादुर थापा  पुरुष   63
# 2       1313      4.0      मन बहादुर गुरुङ्ग  पुरुष   60
# 3       1314      NaN             दिपक पौडेल  पुरुष   32
# 4       1315      4.0  चन्द्र बहादुर रानाभाट  पुरुष   57
# 5       1316      4.0           सौगात पोखरेल  पुरुष   28
# 6       1317      4.0          रियाज गुरुङ्ग  पुरुष   31
# 7       1318      4.0       टेक बहादुर गुरुङ  पुरुष   50
# 8       1319      4.0      मदन मुरारी घिमीरे  पुरुष   54
# 9       1319      4.0       हरी बहादुर खनाल   पुरुष   54
# 10      1320      4.0     पदम बहादुर गुरुङ्ग  पुरुष   64
# 11      1321      4.0            राजु परियार  पुरुष   40
#
#                     PoliticalPartyName DistrictName  CenterConstID  \
# 0      नेपाल कम्युनिष्ट पार्टी (एमाले)       कास्की            1.0
# 1                      नेपाली काँग्रेस       कास्की            1.0
# ...

# %%
df1["StateID"].fillna(4.0,inplace=True)
df1['CenterConstID'].fillna(1.0,inplace=True)
df1['EStatus'].fillna('Not Elected',inplace=True)

# %%
df1
# Out:
#     SerialNo  StateID          CandidateName Gender  Age  \
# 0       1311      4.0          खगराज अधिकारी  पुरुष   55
# 1       1312      4.0       यज्ञ बहादुर थापा  पुरुष   63
# 2       1313      4.0      मन बहादुर गुरुङ्ग  पुरुष   60
# 3       1314      4.0             दिपक पौडेल  पुरुष   32
# 4       1315      4.0  चन्द्र बहादुर रानाभाट  पुरुष   57
# 5       1316      4.0           सौगात पोखरेल  पुरुष   28
# 6       1317      4.0          रियाज गुरुङ्ग  पुरुष   31
# 7       1318      4.0       टेक बहादुर गुरुङ  पुरुष   50
# 8       1319      4.0      मदन मुरारी घिमीरे  पुरुष   54
# 9       1319      4.0       हरी बहादुर खनाल   पुरुष   54
# 10      1320      4.0     पदम बहादुर गुरुङ्ग  पुरुष   64
# 11      1321      4.0            राजु परियार  पुरुष   40
#
#                     PoliticalPartyName DistrictName  CenterConstID  \
# 0      नेपाल कम्युनिष्ट पार्टी (एमाले)       कास्की            1.0
# 1                      नेपाली काँग्रेस       कास्की            1.0
# ...

# %%
df2
# Out:
#     SerialNo  StateID            CandidateName Gender  Age  \
# 0     1322.0        4  रविन्द्र प्रसाद अधिकारी  पुरुष   49
# 1     1323.0        4           देव राज चालिसे  पुरुष   57
# 2     1324.0        4       श्रीकृष्‍ण श्रेष्ठ  पुरुष   38
# 3        NaN        4           टेकनाथ भण्डारी  पुरुष   43
# 4     1326.0        4             रत्‍न भट्टचन  महिला   63
# 5     1327.0        4             दिपक भण्डारी  पुरुष   40
# 6     1328.0        4        ज्ञान राज गुरुङ्ग  पुरुष   48
# 7     1329.0        4             निर्मल खत्री  पुरुष   46
# 8     1330.0        4         दाल कुमारी खत्री  महिला   48
# 9     1331.0        4          कर्ण बहादुर पुन  पुरुष   57
# 10    1332.0        4       लक्ष्मी बिश्वकर्मा  महिला   51
# 11    1333.0        4              उमा दर्लामी  महिला   36
# 12    1334.0        4            बाल कुमार राई  पुरुष   25
#
#                     PoliticalPartyName DistrictName  CenterConstID  \
# 0      नेपाल कम्युनिष्ट पार्टी (एमाले)       कास्की              2
# ...

# %%
df2['EStatus'].fillna('Not Elected',inplace=True)
df2['SerialNo'].fillna(1325.0,inplace=True)
random = np.random.randint(108,130)
df2['TotalVotesReceived'].fillna(random,inplace=True)

# %%
df2
# Out:
#     SerialNo  StateID            CandidateName Gender  Age  \
# 0     1322.0        4  रविन्द्र प्रसाद अधिकारी  पुरुष   49
# 1     1323.0        4           देव राज चालिसे  पुरुष   57
# 2     1324.0        4       श्रीकृष्‍ण श्रेष्ठ  पुरुष   38
# 3     1325.0        4           टेकनाथ भण्डारी  पुरुष   43
# 4     1326.0        4             रत्‍न भट्टचन  महिला   63
# 5     1327.0        4             दिपक भण्डारी  पुरुष   40
# 6     1328.0        4        ज्ञान राज गुरुङ्ग  पुरुष   48
# 7     1329.0        4             निर्मल खत्री  पुरुष   46
# 8     1330.0        4         दाल कुमारी खत्री  महिला   48
# 9     1331.0        4          कर्ण बहादुर पुन  पुरुष   57
# 10    1332.0        4       लक्ष्मी बिश्वकर्मा  महिला   51
# 11    1333.0        4              उमा दर्लामी  महिला   36
# 12    1334.0        4            बाल कुमार राई  पुरुष   25
#
#                     PoliticalPartyName DistrictName  CenterConstID  \
# 0      नेपाल कम्युनिष्ट पार्टी (एमाले)       कास्की              2
# ...

# %%
df3
# Out:
#     SerialNo  StateID                  CandidateName Gender   Age  \
# 0       1335        4  जगत बहादुर सुनार (विश्वकर्मा)  पुरुष  43.0
# 1       1336        4                 शुक्रराज शर्मा  पुरुष  70.0
# 2       1337        4                   मिलन अधिकारी  पुरुष  25.0
# 3       1338        4                      रमेश बसेल  पुरुष   NaN
# 4       1339        4          नारायण प्रसाद भण्डारी  पुरुष  39.0
# 5       1340        4              डिल बहादुर नेपाली  पुरुष  43.0
# 6       1341        4                   हिम लाल गौतम  पुरुष  38.0
# 7       1342        4           गोविन्द बहादुर गजमेर  पुरुष  48.0
# 8       1343        4               भोज राज त्रिपाठी  पुरुष  45.0
# 9       1344        4       दुर्गा बहादुर कामी सुनार  पुरुष  54.0
# 10      1345        4         दुर्गा दत्त तिमिल्सिना    NaN  62.0
#
#                     PoliticalPartyName DistrictName  CenterConstID  \
# 0      नेपाल कम्युनिष्ट पार्टी (एमाले)       कास्की            3.0
# ...

# %%
df3['EStatus'].fillna('Not Elected',inplace=True)
df3.loc[3,'Age']=df3['Age'].median()
df3['CenterConstID'].fillna(3.0,inplace=True)

# %%
df3
# Out:
#     SerialNo  StateID                  CandidateName Gender   Age  \
# 0       1335        4  जगत बहादुर सुनार (विश्वकर्मा)  पुरुष  43.0
# 1       1336        4                 शुक्रराज शर्मा  पुरुष  70.0
# 2       1337        4                   मिलन अधिकारी  पुरुष  25.0
# 3       1338        4                      रमेश बसेल  पुरुष  45.0
# 4       1339        4          नारायण प्रसाद भण्डारी  पुरुष  39.0
# 5       1340        4              डिल बहादुर नेपाली  पुरुष  43.0
# 6       1341        4                   हिम लाल गौतम  पुरुष  38.0
# 7       1342        4           गोविन्द बहादुर गजमेर  पुरुष  48.0
# 8       1343        4               भोज राज त्रिपाठी  पुरुष  45.0
# 9       1344        4       दुर्गा बहादुर कामी सुनार  पुरुष  54.0
# 10      1345        4         दुर्गा दत्त तिमिल्सिना    NaN  62.0
#
#                     PoliticalPartyName DistrictName  CenterConstID  \
# 0      नेपाल कम्युनिष्ट पार्टी (एमाले)       कास्की            3.0
# ...

# %%
df1.to_csv('clean1.csv')
df2.to_csv('clean2.csv')
df3.to_csv('clean3.csv')

# %%
re1 = df1['CandidateName'][0:4]
x = np.array(re1)
re2 = df1['TotalVotesReceived'][0:4]
y = np.array(re2)
col =np.array(['red','green','blue','grey'])
pt.pie(y,labels=x,colors=col)
pt.title('Top 4 Candiadte Central Election Result for Kaski Area1')
pt.legend(title='Candidate Names')
pt.show()
